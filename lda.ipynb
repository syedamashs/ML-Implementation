# %% [markdown]
# <a href="https://colab.research.google.com/github/mouleshgs/ml/blob/main/lda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# %%
# Step 1: Load dataset
iris = load_iris()
X = iris.data   # features (4D)
y = iris.target # labels (3 classes)

# %%
# Step 2: Standardize data
X_scaled = StandardScaler().fit_transform(X)

# Step 3: Apply LDA (reduce to 2 components)
lda = LDA(n_components=2)
X_lda = lda.fit_transform(X_scaled, y)

# %%
# Step 4: Plot results
plt.figure(figsize=(8,6))
scatter = plt.scatter(X_lda[:,0], X_lda[:,1], c=y, cmap='viridis', edgecolor='k', s=80)

plt.xlabel("Linear Discriminant 1")
plt.ylabel("Linear Discriminant 2")
plt.title("LDA on Iris Dataset (2D)")
plt.legend(handles=scatter.legend_elements()[0], labels=list(iris.target_names))
plt.show()
